# %% [markdown]
# <a href="https://colab.research.google.com/github/KevinEnder/mols2grid_tutoriales/blob/main/Introduccion_mols2grid_YT.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <div style="background-color:lightgreen; border-style: dotted;border-color: yellow;text-align:center;color:blue;font-size:20px;border-radius: 50px;padding: 20px 20px;"><strong> Kevin Ender Taype Huanca, undergraduate chemistry student-Universidad Nacional de Ingeniería (UNI)-Lima-Perú
#
# email: kevin.taype.h@uni.pe</strong></div>
#
#
# # Introducción a mols2grid 🐉

# %%
#Sincronizar Google Colab con mi Drive para poder acceder a mis archivos que tenga en mi Drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# La manera más rápida y práctica para instalar mols2grid en Google Colab
# !pip install rdkit-pypi mols2grid
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 36.8 MB 1.2 MB/s
# ...

# %%
#CAmbio a el directorio de trabajo en el cual me encuentro
# %cd /content/drive/MyDrive/Classroom/Machine_Learning_for_Chemists_Kevin_Ender_Taype_Huanca/RDKit
# Out:
# /content/drive/MyDrive/Classroom/Machine_Learning_for_Chemists_Kevin_Ender_Taype_Huanca/RDKit

# %%
#Listo los archivos que tengo en mi directorio actual
# !ls
# Out:
#  delaney-processed.csv		   mols2grid_2.ipynb
#  Introduccion_mols2grid_YT.ipynb   RDKit_visualizacion.ipynb
# 'Molecular descriptors.ipynb'	   rkdit_conda_introduccion.ipynb
#  mols2grid_1.ipynb		   solubility.test.sdf

# %%
#Opcionalmente
# ! wget https://raw.githubusercontent.com/deepchem/deepchem/master/datasets/delaney-processed.csv

# %%
#Importo librerías c:
import mols2grid
import pandas as pd

# %% [markdown]
# # Primer ejemplo 🙈

# %%
#Leer mi archivo y viasualizar los títulos de las columnas o features
df = pd.read_csv("./delaney-processed.csv")
print(list(df))
# Out:
# ['Compound ID', 'ESOL predicted log solubility in mols per litre', 'Minimum Degree', 'Molecular Weight', 'Number of H-Bond Donors', 'Number of Rings', 'Number of Rotatable Bonds', 'Polar Surface Area', 'measured log solubility in mols per litre', 'smiles']

# %%
df
# Out:
#          Compound ID  ESOL predicted log solubility in mols per litre  \
# 0          Amigdalin                                           -0.974
# 1           Fenfuram                                           -2.885
# 2             citral                                           -2.579
# 3             Picene                                           -6.618
# 4          Thiophene                                           -2.232
# ...              ...                                              ...
# 1123       halothane                                           -2.608
# 1124          Oxamyl                                           -0.908
# 1125       Thiometon                                           -3.323
# 1126  2-Methylbutane                                           -2.245
# 1127        Stirofos                                           -4.320
#
#       Minimum Degree  Molecular Weight  Number of H-Bond Donors  \
# ...

# %%
df.head()
# Out:
#   Compound ID  ESOL predicted log solubility in mols per litre  \
# 0   Amigdalin                                           -0.974
# 1    Fenfuram                                           -2.885
# 2      citral                                           -2.579
# 3      Picene                                           -6.618
# 4   Thiophene                                           -2.232
#
#    Minimum Degree  Molecular Weight  Number of H-Bond Donors  Number of Rings  \
# 0               1           457.432                        7                3
# 1               1           201.225                        1                2
# 2               1           152.237                        0                0
# 3               2           278.354                        0                5
# 4               2            84.143                        0                1
#
#    Number of Rotatable Bonds  Polar Surface Area  \
# 0                          7              202.32
# ...

# %% [markdown]
# * Observación: 😼
#
# * Para el input de entrada de mols2grid se puede emplear un archivo SDF, UN DataFrame, o una lista de moléculas de RDKit
# * Para mostrar la interface se puede insertar un pandas DataFrame como un input que contenga una columna de moléculas RDKit (especificando 'mol_col=...'), o SMILES string (especificando 'smiles_col=..')
#
#
# We can also use a pandas DataFrame as input, containing a column of RDKit molecules (specified using `mol_col=...`) or SMILES strings (specified using `smiles_col=...`):

# %%
#Emplearé una columna de SMILES
mols2grid.display(df, smiles_col="smiles")
# Out:
# <script>
#     function fit_height(obj) {
#         obj.style.height = 0;
#         var height = obj.contentDocument.body.scrollHeight + 18 + 'px';
#         obj.style.height = height;
#     }
# </script>
# <iframe class="mols2grid-iframe" frameborder="0" width="100%"
#
# height="200"
#
#
# allow="clipboard-write"
#
# srcdoc="&lt;html&gt;
#   &lt;meta charset=&quot;utf-8&quot;&gt;
#   &lt;head&gt;
#     &lt;style&gt;
#     #mols2grid.gridcontainer {
#     display: block;
#     padding-left: 1em;
#     max-width: 820px;
#     width: 820px;
# }
# #mols2grid .cell {
#     border: 1px solid #cccccc;
#     text-align: center;
#     vertical-align: top;
#     max-width: 160px;
#     width: 160px;
#     font-family: &#x27;DejaVu&#x27;, sans-serif;
#     font-size: 12pt;
#     padding: 0;
#     margin: 0px;
#     float: left;
# }
# #mols2grid .cell:hover {
#     background-color: #e7e7e7 !important;
# }
# #mols2grid .cell .data-img {
#     padding: 0;
#     margin: 0;
# }
# ...

# %%
#FILTRANDO POR FILAS
#Para idenficar las filas, se puede hacer de la siguiente manera:
#i) Idenficar las filas a través de los índices de las mismas (0, 1, 2, etc.) como si fueran listas de Python
# Seleccionando filas, a traves de los indices
df.loc[4]
#También puedo escribir: df.iloc[4] y me dará el mismo resultado
# Out:
# Compound ID                                        Thiophene
# ESOL predicted log solubility in mols per litre       -2.232
# Minimum Degree                                             2
# Molecular Weight                                      84.143
# Number of H-Bond Donors                                    0
# Number of Rings                                            1
# Number of Rotatable Bonds                                  0
# Polar Surface Area                                       0.0
# measured log solubility in mols per litre              -1.33
# smiles                                               c1ccsc1
# Name: 4, dtype: object

# %%
df.loc[9]
# Out:
# Compound ID                                                                                Rotenone
# ESOL predicted log solubility in mols per litre                                              -5.246
# Minimum Degree                                                                                    1
# Molecular Weight                                                                            394.423
# Number of H-Bond Donors                                                                           0
# Number of Rings                                                                                   5
# Number of Rotatable Bonds                                                                         3
# Polar Surface Area                                                                            63.22
# measured log solubility in mols per litre                                                     -4.42
# ...

# %% [markdown]
# #Segundo Ejemplo 👻
#
# * Qué pasaría si quiero analizar/visualizar en un rango determinado🤔

# %%
#Solo para el caso de los últimos 10 compuestos
df_2do_ejemplo= df.tail(10)
df_2do_ejemplo
# Out:
#                 Compound ID  ESOL predicted log solubility in mols per litre  \
# 1118       Isobutyl acetate                                           -1.463
# 1119  2,2,3-Trimethylbutane                                           -2.922
# 1120       2,3,3',4,4'6-PCB                                           -7.746
# 1121         Phthalonitrile                                           -1.717
# 1122         m-Nitrotoluene                                           -2.640
# 1123              halothane                                           -2.608
# 1124                 Oxamyl                                           -0.908
# 1125              Thiometon                                           -3.323
# 1126         2-Methylbutane                                           -2.245
# 1127               Stirofos                                           -4.320
#
#       Minimum Degree  Molecular Weight  Number of H-Bond Donors  \
# ...

# %%
#Ahora emplearé SMILES
mols2grid.display(df_2do_ejemplo, smiles_col="smiles")
# Out:
# <script>
#     function fit_height(obj) {
#         obj.style.height = 0;
#         var height = obj.contentDocument.body.scrollHeight + 18 + 'px';
#         obj.style.height = height;
#     }
# </script>
# <iframe class="mols2grid-iframe" frameborder="0" width="100%"
#
# height="200"
#
#
# allow="clipboard-write"
#
# srcdoc="&lt;html&gt;
#   &lt;meta charset=&quot;utf-8&quot;&gt;
#   &lt;head&gt;
#     &lt;style&gt;
#     #mols2grid.gridcontainer {
#     display: block;
#     padding-left: 1em;
#     max-width: 820px;
#     width: 820px;
# }
# #mols2grid .cell {
#     border: 1px solid #cccccc;
#     text-align: center;
#     vertical-align: top;
#     max-width: 160px;
#     width: 160px;
#     font-family: &#x27;DejaVu&#x27;, sans-serif;
#     font-size: 12pt;
#     padding: 0;
#     margin: 0px;
#     float: left;
# }
# #mols2grid .cell:hover {
#     background-color: #e7e7e7 !important;
# }
# #mols2grid .cell .data-img {
#     padding: 0;
#     margin: 0;
# }
# ...

# %%
#Si quisiera obtener un rango de índices específico
intento_final= df.iloc[0:3] #Lo curioso es que cuando coloco: df.loc[0:3] me devuelve desde la fila 0 hasta la 3 v:
#iloc-->Es para filtrar por índices
#loc--> Es para filtrar por idenfificadores
intento_final
# Out:
#   Compound ID  ESOL predicted log solubility in mols per litre  \
# 0   Amigdalin                                           -0.974
# 1    Fenfuram                                           -2.885
# 2      citral                                           -2.579
#
#    Minimum Degree  Molecular Weight  Number of H-Bond Donors  Number of Rings  \
# 0               1           457.432                        7                3
# 1               1           201.225                        1                2
# 2               1           152.237                        0                0
#
#    Number of Rotatable Bonds  Polar Surface Area  \
# 0                          7              202.32
# 1                          2               42.24
# 2                          4               17.07
#
#    measured log solubility in mols per litre  \
# 0                                      -0.77
# 1                                      -3.30
# 2                                      -2.06
#
# ...

# %%
#Ahora emplearé SMILES
mols2grid.display(intento_final, smiles_col="smiles")
# Out:
# <script>
#     function fit_height(obj) {
#         obj.style.height = 0;
#         var height = obj.contentDocument.body.scrollHeight + 18 + 'px';
#         obj.style.height = height;
#     }
# </script>
# <iframe class="mols2grid-iframe" frameborder="0" width="100%"
#
# height="200"
#
#
# allow="clipboard-write"
#
# srcdoc="&lt;html&gt;
#   &lt;meta charset=&quot;utf-8&quot;&gt;
#   &lt;head&gt;
#     &lt;style&gt;
#     #mols2grid.gridcontainer {
#     display: block;
#     padding-left: 1em;
#     max-width: 820px;
#     width: 820px;
# }
# #mols2grid .cell {
#     border: 1px solid #cccccc;
#     text-align: center;
#     vertical-align: top;
#     max-width: 160px;
#     width: 160px;
#     font-family: &#x27;DejaVu&#x27;, sans-serif;
#     font-size: 12pt;
#     padding: 0;
#     margin: 0px;
#     float: left;
# }
# #mols2grid .cell:hover {
#     background-color: #e7e7e7 !important;
# }
# #mols2grid .cell .data-img {
#     padding: 0;
#     margin: 0;
# }
# ...
